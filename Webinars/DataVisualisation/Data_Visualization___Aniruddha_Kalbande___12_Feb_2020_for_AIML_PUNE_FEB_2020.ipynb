# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
df1 = DataFrame({'A':[1,4,np.nan,np.nan],
                'B':[2,5,8,np.nan],
                'C':[3,np.nan,np.nan,np.nan]})

# %%
df1
# Out:
#      A    B    C
# 0  1.0  2.0  3.0
# 1  4.0  5.0  NaN
# 2  NaN  8.0  NaN
# 3  NaN  NaN  NaN

# %%
df1.isnull()
# Out:
#        A      B      C
# 0  False  False  False
# 1  False  False   True
# 2   True  False   True
# 3   True   True   True

# %%
df1.notnull()
# Out:
#        A      B      C
# 0   True   True   True
# 1   True   True  False
# 2  False   True  False
# 3  False  False  False

# %%
df1['A']
# Out:
# 0    1.0
# 1    4.0
# 2    NaN
# 3    NaN
# Name: A, dtype: float64

# %%
df1['A'].isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# Name: A, dtype: bool

# %%
df1
# Out:
#      A    B    C
# 0  1.0  2.0  3.0
# 1  4.0  5.0  NaN
# 2  NaN  8.0  NaN
# 3  NaN  NaN  NaN

# %%
df1.isnull().sum() #count of null values
# Out:
# A    2
# B    1
# C    3
# dtype: int64

# %%
df1.fillna(0)
# Out:
#      A    B    C
# 0  1.0  2.0  3.0
# 1  4.0  5.0  0.0
# 2  0.0  8.0  0.0
# 3  0.0  0.0  0.0

# %%
df1['A'] = df1['A'].fillna(df1['A'].mean())
# Out:
# 0    1.0
# 1    4.0
# 2    2.5
# 3    2.5
# Name: A, dtype: float64

# %%
df1
# Out:
#      A    B    C
# 0  1.0  2.0  3.0
# 1  4.0  5.0  NaN
# 2  NaN  8.0  NaN
# 3  NaN  NaN  NaN

# %%
df1.fillna(method='ffill')
# Out:
#      A    B    C
# 0  1.0  2.0  3.0
# 1  4.0  5.0  3.0
# 2  4.0  8.0  3.0
# 3  4.0  8.0  3.0

# %%
df1.fillna(method='bfill',axis=1)
# Out:
#      A    B    C
# 0  1.0  2.0  3.0
# 1  4.0  5.0  NaN
# 2  8.0  8.0  NaN
# 3  NaN  NaN  NaN

# %%
df1.fillna(method='ffill',axis=1)
# Out:
#      A    B    C
# 0  1.0  2.0  3.0
# 1  4.0  5.0  5.0
# 2  NaN  8.0  8.0
# 3  NaN  NaN  NaN

# %% [raw]
# df1 - Null
# df2 - all the values are there
# np.where(df1.isnull(),df2,df1)

# %%
df1
# Out:
#      A    B    C
# 0  1.0  2.0  3.0
# 1  4.0  5.0  NaN
# 2  NaN  8.0  NaN
# 3  NaN  NaN  NaN

# %%
df1.dropna()
# Out:
#      A    B    C
# 0  1.0  2.0  3.0

# %% [raw]
# Any - Or
# All - And

# %%
df1.dropna(how='any')
# Out:
#      A    B    C
# 0  1.0  2.0  3.0

# %%
df1.dropna(how='all')
# Out:
#      A    B    C
# 0  1.0  2.0  3.0
# 1  4.0  5.0  NaN
# 2  NaN  8.0  NaN

# %%
df1.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %%
df1.dropna(axis=1,how='all')
# Out:
#      A    B    C
# 0  1.0  2.0  3.0
# 1  4.0  5.0  NaN
# 2  NaN  8.0  NaN
# 3  NaN  NaN  NaN

# %%
df1
# Out:
#      A    B    C
# 0  1.0  2.0  3.0
# 1  4.0  5.0  NaN
# 2  NaN  8.0  NaN
# 3  NaN  NaN  NaN

# %%
df1.dropna(thresh = 1) #thresh is w.r.t non null values
# Out:
#      A    B    C
# 0  1.0  2.0  3.0
# 1  4.0  5.0  NaN
# 2  NaN  8.0  NaN

# %%
df1.dropna(thresh=2)
# Out:
#      A    B    C
# 0  1.0  2.0  3.0
# 1  4.0  5.0  NaN

# %%
df1.dropna(thresh=3)
# Out:
#      A    B    C
# 0  1.0  2.0  3.0

# %%
df1.dropna(thresh=2,axis=1)
# Out:
#      A    B
# 0  1.0  2.0
# 1  4.0  5.0
# 2  NaN  8.0
# 3  NaN  NaN

# %%
df1.dropna(thresh=3,axis=1)
# Out:
#      B
# 0  2.0
# 1  5.0
# 2  8.0
# 3  NaN

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x1 = [1,2,3,4,5]
y1 = [10,2,15,20,28]

# %%
plt.plot(x1,y1)
plt.show()

# %%
y2 = [20,10,28,5,31]

# %%
plt.plot(x1,y1)
plt.plot(x1,y2)
plt.show()

# %%
plt.plot(x1,y1,label = 'Line 1',color='r',marker='s',markersize=5,linestyle='-.')
plt.plot(x1,y2,label = 'Line 2',color='b',marker='o',markersize=12)
plt.legend() #use to display the label
plt.grid()
plt.title('Simple Line Graph')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()

# %%
plt.scatter(x1,y1,color='r')
plt.grid()
plt.title('Simple Scatter plot')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()

# %%
df1 = sns.load_dataset('tips')

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df1.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
df1.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df1.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df1.nunique() # Count of Unique Datapoints in a column
# Out:
# total_bill    229
# tip           123
# sex             2
# smoker          2
# day             4
# time            2
# size            6
# dtype: int64

# %%
df1['day'].unique()
# Out:
# [Sun, Sat, Thur, Fri]
# Categories (4, object): [Sun, Sat, Thur, Fri]

# %%
df1['time'].unique()
# Out:
# [Dinner, Lunch]
# Categories (2, object): [Dinner, Lunch]

# %%
for i in df1.columns:
    print(df1[i].unique())
# Out:
# [16.99 10.34 21.01 23.68 24.59 25.29  8.77 26.88 15.04 14.78 10.27 35.26
#  15.42 18.43 14.83 21.58 10.33 16.29 16.97 20.65 17.92 20.29 15.77 39.42
#  19.82 17.81 13.37 12.69 21.7  19.65  9.55 18.35 15.06 20.69 17.78 24.06
#  16.31 16.93 18.69 31.27 16.04 17.46 13.94  9.68 30.4  18.29 22.23 32.4
#  28.55 18.04 12.54 10.29 34.81  9.94 25.56 19.49 38.01 26.41 11.24 48.27
#  13.81 11.02 17.59 20.08 16.45  3.07 20.23 15.01 12.02 17.07 26.86 25.28
#  14.73 10.51 27.2  22.76 17.29 19.44 16.66 10.07 32.68 15.98 34.83 13.03
#  18.28 24.71 21.16 28.97 22.49  5.75 16.32 22.75 40.17 27.28 12.03 12.46
#  11.35 15.38 44.3  22.42 20.92 15.36 20.49 25.21 18.24 14.31 14.    7.25
#  38.07 23.95 25.71 17.31 29.93 10.65 12.43 24.08 11.69 13.42 14.26 15.95
#  12.48 29.8   8.52 14.52 11.38 22.82 19.08 20.27 11.17 12.26 18.26  8.51
#  14.15 16.   13.16 17.47 34.3  41.19 27.05 16.43  8.35 18.64 11.87  9.78
#   7.51 14.07 13.13 17.26 24.55 19.77 29.85 48.17 25.   13.39 16.49 21.5
# ...

# %%
plt.hist(df1['total_bill'])
plt.show()

# %%
plt.hist(df1['total_bill'],bins=5)
plt.show()

# %%
plt.hist(df1['total_bill'],bins=[0,10,20,35,45,55])
plt.xlabel('X Axis')
plt.show()

# %%
df1['total_bill'].plot(kind='hist')
plt.show()

# %%
df1['total_bill'].plot(kind='hist',bins=5,color='r',edgecolor='k')
plt.show()

# %%
sns.distplot(df1['total_bill'])
plt.show()

# %%
sns.distplot(df1['total_bill'],color='r',hist=False)
plt.show()

# %%
sns.distplot(df1['total_bill'],color='r',kde=False)
plt.show()

# %%
sns.kdeplot(df1['total_bill'])
plt.show()

# %%
df1['total_bill'].plot(kind='density')
plt.show()

# %%
df1['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df1['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df1['sex'].value_counts().index
# Out:
# CategoricalIndex(['Male', 'Female'], categories=['Male', 'Female'], ordered=False, dtype='category')

# %%
df1['sex'].value_counts().values
# Out:
# array([157,  87])

# %%
plt.bar(df1['sex'].value_counts().index , df1['sex'].value_counts().values )
plt.show()

# %%
df1['sex'].value_counts().plot(kind='bar',color=['r','g'])
plt.xticks(rotation=0)
plt.show()

# %%
df1['sex'].value_counts().sort_values(ascending=True).plot(kind='bar',color=['r','g'])
plt.xticks(rotation=0)
plt.show()

# %%
plt.barh(df1['sex'].value_counts().index , df1['sex'].value_counts().values )
plt.show()

# %%
df1['sex'].value_counts().sort_values(ascending=True).plot(kind='barh',color=['r','g'])
plt.xticks(rotation=0)
plt.show()

# %%
plt.bar(df1['day'].value_counts().index , df1['day'].value_counts().values )
plt.show()

# %%
plt.pie(df1['day'].value_counts().values,labels=df1['day'].value_counts().index)
plt.show()

# %%
plt.pie(df1['day'].value_counts().values,labels=df1['day'].value_counts().index,autopct='%1.3f%%')
plt.show()

# %%
plt.pie(df1['day'].value_counts().values,labels=df1['day'].value_counts().index,
        autopct='%1.3f%%',explode=[0,0,0,0.2])
plt.show()

# %%
plt.pie(df1['day'].value_counts().values,labels=df1['day'].value_counts().index,
        autopct='%1.3f%%',explode=[0,0.1,0,0.2])
plt.show()

# %%
df1['sex'].value_counts().plot(kind='pie',autopct='%1.3f%%',explode=[0,0.1])
plt.show()

# %%
sns.lmplot(x='total_bill',y='tip',data=df1)
plt.show()

# %%
sns.lmplot(x='total_bill',y='tip',data=df1,fit_reg=False)
plt.show()

# %%
sns.lmplot(x='total_bill',y='tip',data=df1,hue='sex',fit_reg=False)
plt.show()

# %%
sns.lmplot(x='total_bill',y='tip',data=df1,hue='day',fit_reg=False)
plt.show()

# %%
sns.lmplot(x='total_bill',y='tip',data=df1,col='sex',fit_reg=False)
plt.show()

# %%
sns.lmplot(x='total_bill',y='tip',data=df1,col='day',fit_reg=False)
plt.show()

# %%
sns.lmplot(x='total_bill',y='tip',data=df1,row='day',fit_reg=False)
plt.show()

# %%
sns.lmplot(x='total_bill',y='tip',data=df1,row='sex',col='smoker',fit_reg=False)
plt.show()

# %%
sns.lmplot(x='total_bill',y='tip',data=df1,row='sex',col='smoker',fit_reg=False,hue='day')
plt.show()

# %%
sns.boxplot(x='total_bill',data=df1)
plt.show()

# %%
sns.boxplot(x='day',y='total_bill',data=df1)
plt.show()

# %%
plt.boxplot(df1['total_bill'])
plt.show()

# %%
sns.countplot(df1['sex'])
plt.show()

# %%
sns.countplot(df1['day'])
plt.show()

# %%
sns.countplot(x='sex',data=df1,hue='smoker')
plt.show()

# %%
sns.pairplot(df1)
plt.show()

# %%
sns.pairplot(df1,hue='sex')
plt.show()

# %%
df1.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df1.corr(),annot=True)
plt.show()
