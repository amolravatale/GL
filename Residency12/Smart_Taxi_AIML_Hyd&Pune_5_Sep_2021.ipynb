# %%
import gym
import numpy as np
import pickle,os

# %%
env = gym.make("Taxi-v3")

# %%
state = env.reset()

# %%
state
# Out:
# 213

# %%
env.observation_space.n
# Out:
# 500

# %%
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %%
# 6 Possible Actions

# down (0), up (1), right (2), left (3), pick-up (4), and drop-off (5)

# %%
n_states = env.observation_space.n

# %%
n_actions = env.action_space.n

# %%
n_actions
# Out:
# 6

# %%
env.env.s = 4

# %%
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %%
# down (0), up (1), right (2), left (3), pick-up (4), and drop-off (5)

env.step(0)
# Out:
# (104, -1, False, {'prob': 1.0})

# %%
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)

# %%
env.step(2)
# Out:
# (124, -1, False, {'prob': 1.0})

# %%
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)

# %%
env.step(0)
# Out:
# (224, -1, False, {'prob': 1.0})

# %%
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)

# %%
# Random Step taken from all available actions

env.step(env.action_space.sample())
# Out:
# (224, -10, False, {'prob': 1.0})

# %%
# How well does the agent behave when it is allowed completely random actions?

# %%
state = env.reset()
counter = 0
tot_reward = 0
reward = None

while reward != 20:
  state, reward, done, info = env.step(env.action_space.sample())
  counter += 1
  tot_reward += reward


print("Solved in {} Steps with a Total Reward of {}".format(counter,tot_reward))
# Out:
# Solved in 395 Steps with a Total Reward of -1490

# %%
Q = np.zeros([n_states, n_actions])

# %%
Q.shape
# Out:
# (500, 6)

# %%
episodes = 1000
G = 0              # Total Reward
gamma = 0.7

# %%
for episode in range(1,episodes+1):
  done = False
  G, reward = 0, 0 
  state = env.reset()
  firststate = state
  print("Initial State = {} ".format(state))

  while reward != 20:
    action = np.argmax(Q[state])
    state2, reward , done , info = env.step(action)
    Q[state,action] += gamma * (reward + np.max(Q[state2]) - Q[state,action])

    G += reward
    state = state2
# Out:
# Initial State = 187
# Initial State = 3
# Initial State = 311
# Initial State = 93
# Initial State = 123
# Initial State = 432
# Initial State = 143
# Initial State = 482
# Initial State = 44
# Initial State = 444
# Initial State = 464
# Initial State = 287
# Initial State = 174
# Initial State = 353
# Initial State = 31
# Initial State = 28
# Initial State = 493
# Initial State = 168
# Initial State = 226
# Initial State = 424
# Initial State = 267
# Initial State = 213
# Initial State = 184
# Initial State = 54
# Initial State = 191
# Initial State = 114
# Initial State = 148
# Initial State = 23
# Initial State = 254
# Initial State = 7
# Initial State = 131
# Initial State = 361
# Initial State = 401
# Initial State = 494
# Initial State = 92
# Initial State = 82
# Initial State = 421
# Initial State = 153
# Initial State = 409
# Initial State = 211
# Initial State = 173
# Initial State = 247
# Initial State = 231
# Initial State = 83
# Initial State = 263
# Initial State = 29
# ...

# %%
Q
# Out:
# array([[ 0.        ,  0.        ,  0.        ,  0.        ,  0.        ,
#          0.        ],
#        [-5.8866247 , -6.3       , -6.72450753, -6.3       , 11.        ,
#         -7.        ],
#        [-4.227783  , -4.2       , -4.19433   , -4.2       , 15.        ,
#         -7.        ],
#        ...,
#        [-3.5       , 16.        , -3.5       , -3.4381907 , -7.        ,
#         -7.        ],
#        [-5.6       , -5.65269738, -5.6       , -5.955774  , -7.        ,
#         -7.        ],
#        [-1.4       , -1.4       , -1.4       ,  8.89      , -7.        ,
#         -7.        ]])
