# %%
import pandas as pds
import matplotlib.pyplot as plt
import seaborn as sns

# %%
auto = pds.read_csv("/home/amol/GL/PythonForMachineLearning/LabExercises/Automobile.csv")

# %%
auto.dtypes
# Out:
# symboling                int64
# normalized_losses        int64
# make                    object
# fuel_type               object
# aspiration              object
# number_of_doors         object
# body_style              object
# drive_wheels            object
# engine_location         object
# wheel_base             float64
# length                 float64
# width                  float64
# height                 float64
# curb_weight              int64
# engine_type             object
# number_of_cylinders     object
# engine_size              int64
# fuel_system             object
# bore                   float64
# stroke                 float64
# compression_ratio      float64
# horsepower               int64
# peak_rpm                 int64
# city_mpg                 int64
# highway_mpg              int64
# price                    int64
# dtype: object

# %%
#this plot is useful for univariate variable analyses...that too for numeric and not categorical data
sns.distplot(auto['wheel_base'],bins=4,kde=True)
plt.show()

# %%
sns.jointplot(auto['horsepower'],auto['peak_rpm'],kind="reg")
plt.show()

# %%
ds = sns.load_dataset("tips")

# %%
ds.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
sns.jointplot(y=ds['tip'],x=ds['total_bill'])
