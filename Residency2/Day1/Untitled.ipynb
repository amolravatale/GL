# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/home/amol/GL/Residency2/car-mpg.csv")

# %%
df.head()
# Out:
#     mpg  cyl   disp   hp    wt   acc  yr  origin                   car name
# 0  18.0    8  307.0  130  3504  12.0  70       1  chevrolet chevelle malibu
# 1  15.0    8  350.0  165  3693  11.5  70       1          buick skylark 320
# 2  18.0    8  318.0  150  3436  11.0  70       1         plymouth satellite
# 3  16.0    8  304.0  150  3433  12.0  70       1              amc rebel sst
# 4  17.0    8  302.0  140  3449  10.5  70       1                ford torino

# %%
del df['hp']

# %%
df.describe()
# Out:
#               mpg         cyl        disp           wt         acc
# count  398.000000  398.000000  398.000000   398.000000  398.000000
# mean    23.514573    5.454774  193.425879  2970.424623   15.568090
# std      7.815984    1.701004  104.269838   846.841774    2.757689
# min      9.000000    3.000000   68.000000  1613.000000    8.000000
# 25%     17.500000    4.000000  104.250000  2223.750000   13.825000
# 50%     23.000000    4.000000  148.500000  2803.500000   15.500000
# 75%     29.000000    8.000000  262.000000  3608.000000   17.175000
# max     46.600000    8.000000  455.000000  5140.000000   24.800000

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-f90ad2589452> in <module>
#       1 l1=[5,5,5,5]
# ----> 2 l1.mean()
#
# AttributeError: 'list' object has no attribute 'mean'

# %%
sc = StandardScaler()

# %%
scaledf = pd.DataFrame(sc.fit_transform(df))
scaledf.columns = df.columns
scaledf.head()
# Out:
#         mpg       cyl      disp        wt       acc
# 0 -0.706439  1.498191  1.090604  0.630870 -1.295498
# 1 -1.090751  1.498191  1.503514  0.854333 -1.477038
# 2 -0.706439  1.498191  1.196232  0.550470 -1.658577
# 3 -0.962647  1.498191  1.061796  0.546923 -1.295498
# 4 -0.834543  1.498191  1.042591  0.565841 -1.840117

# %%
sns.pairplot(scaledf,diag_kind="kde")
