# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/amol/Documents/GITRepo/GL/MiniCapstoneProject/DataSet/USCounty/archive/covid_us_county_data.csv")

# %%
df.dtypes
# Out:
# fips          float64
# county         object
# state          object
# lat           float64
# long          float64
# date           object
# cases           int64
# state_code     object
# deaths          int64
# dtype: object

# %%
df.shape
# Out:
# (965260, 9)

# %%
#Lets set the correct format of columns
# fips -> numeric, date -> date type 
df['date'] = pd.to_datetime(df['date'])

# %%
df[['fips']] = df[['fips']].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-ddbad46821dc> in <module>()
# ----> 1 df[['fips']] = df[['fips']].astype(int)
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4995             # else, only a single dtype is given
#    4996             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4997                                          **kwargs)
# ...

# %%
df.dtypes
# Out:
# fips                 float64
# county                object
# state                 object
# lat                  float64
# long                 float64
# date          datetime64[ns]
# cases                  int64
# state_code            object
# deaths                 int64
# dtype: object

# %%
df[7777:9999]
# Out:
#         fips    county    state        lat       long       date  cases  \
# 7777  1053.0  Escambia  Alabama  31.125679 -87.159187 2020-10-11   1684
# 7778  1053.0  Escambia  Alabama  31.125679 -87.159187 2020-10-12   1684
# 7779  1053.0  Escambia  Alabama  31.125679 -87.159187 2020-10-13   1690
# 7780  1053.0  Escambia  Alabama  31.125679 -87.159187 2020-10-14   1687
# 7781  1053.0  Escambia  Alabama  31.125679 -87.159187 2020-10-15   1691
# 7782  1053.0  Escambia  Alabama  31.125679 -87.159187 2020-10-16   1695
# 7783  1053.0  Escambia  Alabama  31.125679 -87.159187 2020-10-17   1702
# 7784  1053.0  Escambia  Alabama  31.125679 -87.159187 2020-10-18   1703
# 7785  1053.0  Escambia  Alabama  31.125679 -87.159187 2020-10-19   1709
# 7786  1053.0  Escambia  Alabama  31.125679 -87.159187 2020-10-20   1713
# 7787  1053.0  Escambia  Alabama  31.125679 -87.159187 2020-10-21   1714
# 7788  1053.0  Escambia  Alabama  31.125679 -87.159187 2020-10-22   1719
# ...
