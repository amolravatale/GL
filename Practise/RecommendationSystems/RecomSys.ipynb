# %%
import pandas as pd
import numpy as np

# %%
dfMovies = pd.read_csv("movies.csv")

# %%
dfRatings = pd.read_csv("ratings.csv")

# %%
dfMovies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
dfRatings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
"""
1) Find out most popular movie - say to 10... wathced by most users and givein top ratings
"""

# %%
dfMovies['Year'] = dfMovies['title'].map(lambda x : x[len(x)-6:])

# %%
dfMovies.dtypes
# Out:
# movieId     int64
# title      object
# genres     object
# Year       object
# dtype: object

# %%
dfRatings.dtypes
# Out:
# userId         int64
# movieId        int64
# rating       float64
# timestamp      int64
# dtype: object

# %%
#dfRatings.groupby('movieId').mean().sort_values(by='rating', ascending=False)
dfRatings.groupby('movieId').count().sort_values(by='userId', ascending=False)
# Out:
#          userId  rating  timestamp
# movieId
# 356         341     341        341
# 296         324     324        324
# 318         311     311        311
# 593         304     304        304
# 260         291     291        291
# 480         274     274        274
# 2571        259     259        259
# 1           247     247        247
# 527         244     244        244
# 589         237     237        237
# 1196        234     234        234
# 110         228     228        228
# 1270        226     226        226
# 608         224     224        224
# 2858        220     220        220
# 1198        220     220        220
# 780         218     218        218
# 1210        217     217        217
# 588         215     215        215
# 457         213     213        213
# 590         202     202        202
# 2959        202     202        202
# 47          201     201        201
# 50          201     201        201
# 364         200     200        200
# ...

# %%
dfmovierating = pd.merge(dfMovies, dfRatings, on='movieId')

# %%
dfmovieWatchCount= dfmovierating.groupby('movieId').count().sort_values(by='userId', ascending=False)

# %%
dfuserwatchCount= dfmovierating.groupby('userId').count().sort_values(by='userId', ascending=False)

# %%
dfuserwatchCount[dfuserwatchCount.index==671]
# Out:
#         movieId  title  genres  Year  rating  timestamp
# userId
# 671         115    115     115   115     115        115

# %%
dfmovierating.columns
# Out:
# Index(['movieId', 'title', 'genres', 'Year', 'userId', 'rating', 'timestamp'], dtype='object')

# %%
dfmovierating.groupby('movieId')['rating'].mean().head(10).sort_values(ascending=False)
# Out:
# movieId
# 6     3.884615
# 1     3.872470
# 8     3.800000
# 10    3.450820
# 2     3.401869
# 7     3.283019
# 5     3.267857
# 3     3.161017
# 9     3.150000
# 4     2.384615
# Name: rating, dtype: float64

# %%
dfmovierating.groupby('title')['rating'].mean().head(10).sort_values(ascending=False).head()
# Out:
# title
# 'night Mother (1986)           5.000000
# $9.99 (2008)                   3.833333
# (500) Days of Summer (2009)    3.755556
# 'Salem's Lot (2004)            3.500000
# 'burbs, The (1989)             3.052632
# Name: rating, dtype: float64

# %%
# Out:
# title
# "Great Performances" Cats (1998)                                          1.750000
# $9.99 (2008)                                                              3.833333
# 'Hellboy': The Seeds of Creation (2004)                                   2.000000
# 'Neath the Arizona Skies (1934)                                           0.500000
# 'Round Midnight (1986)                                                    2.250000
# 'Salem's Lot (2004)                                                       3.500000
# 'Til There Was You (1997)                                                 2.625000
# 'burbs, The (1989)                                                        3.052632
# 'night Mother (1986)                                                      5.000000
# (500) Days of Summer (2009)                                               3.755556
# *batteries not included (1987)                                            3.142857
# ...
