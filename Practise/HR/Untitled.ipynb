# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dfhr = pd.read_csv("/home/amol/GITRepo/GL/Practise/HR/HR.txt",sep="\t")

# %%
dfhr.head()
# Out:
#   Individual  Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0        Ind1       Yes   41               1       1102           1
# 1        Ind2        No   49               2        279           2
# 2        Ind3       Yes   37               1       1373           2
# 3        Ind4        No   33               2       1392           2
# 4        Ind5        No   27               1        591           2
#
#    DistanceFromHome  Education  EducationField  EmployeeCount  ...  \
# 0                 1          2               1              1  ...
# 1                 8          1               1              1  ...
# 2                 2          2               6              1  ...
# 3                 3          4               1              1  ...
# 4                 2          1               2              1  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                         1             80                 0
# ...

# %%
dfhr.dtypes
# Out:
# Individual                  object
# Attrition                   object
# Age                          int64
# BusinessTravel               int64
# DailyRate                    int64
# Department                   int64
# DistanceFromHome             int64
# Education                    int64
# EducationField               int64
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                       int64
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                      int64
# JobSatisfaction              int64
# MaritalStatus                int64
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                     int64
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
sns.lmplot(x="Age",y="MonthlyIncome",data=dfhr[dfhr["Education"]==5])

# %%
sns.boxplot(x="Age",y="MonthlyIncome",data=dfhr[dfhr["Education"]==5],hue="Education")

# %%
dfhr[dfhr["Education"]==5]
# Out:
#      Individual  Attrition  Age  BusinessTravel  DailyRate  Department  \
# 52         Ind53        No   44               1       1488           1
# 56         Ind57        No   35               2        853           1
# 61         Ind62        No   38               2        653           2
# 142       Ind143        No   38               1        364           2
# 151       Ind152        No   35               1        662           1
# 169       Ind170        No   32               1        120           2
# 208       Ind209        No   40               3       1151           2
# 329       Ind330        No   47               1       1482           2
# 337       Ind338        No   29               1        738           2
# 348       Ind349        No   42               1        810           2
# 358       Ind359        No   36               3        845           1
# 398       Ind399        No   37               3       1063           2
# ...
