# %% [markdown]
# # Objective
#
# To review the Naive Bayes algorithm

# %% [markdown]
# ## Preliminaries

# %%
import pandas as pd

from sklearn.feature_extraction.text import CountVectorizer

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# # The Algorithm
#
# $$
# P(A|B) = \dfrac{P(A) P(B|A)}{P(B)}
# $$

# %% [markdown]
# $$
# P(y|x_1, x_2,\ldots,x_n)=\dfrac{P(y) \times [P(x_1|y) P(x_2|y) \ldots P(x_n|y)]}{P(x_1, x_2, \ldots, x_n)}
# $$

# %% [markdown]
# When the features are categorical, count of the feature in each of the examples allows us to determine the probabilities. Here we assume that each of the categorical features are independent.

# %% [markdown]
# $$
# P(y = \text{5-star}| \text{'wow'}, \text{'awesome'}) = \dfrac{P(\text{5-star}) \times [P(\text{'wow'}| \text{5-star}) P(\text{'awesome'}| \text{5-star})]}{P(\text{'wow}, \text{'awesome'})}
# $$

# %% [markdown]
# When the features are numeric, we assume the distribution of the features to be Gaussian and compute the conditional probability distributions. So, for numeric features we have two assumptions - independence and normality. These are rather strong assumptions and hence the 'naive'.

# %% [markdown]
# $$
# P(y = Diabetes|BP, Glucose) = \dfrac{P(Diabetes) \times [P(BP|Diabetes) P(Glucose|Diabetes)]}{P(BP, Glucose)}
# $$

# %% [markdown]
# # Example: **Yelp**

# %% [markdown]
# ## Data

# %%
yelp_df = pd.read_csv("/content/drive/MyDrive/AI-ML/supervised-learning-revision/Day2/data/yelp.csv")

# %%
yelp_df.head()
# Out:
#               business_id        date  ... useful  funny
# 0  9yKzy9PApeiPPOUJEtnvkg  2011-01-26  ...      5      0
# 1  ZRJwVLyzEJq1VAihDhYiow  2011-07-27  ...      0      0
# 2  6oRAC4uyJCsJl1X0WZpVSA  2012-06-14  ...      1      0
# 3  _1QQZuf4zZOyFCvXc0o6Vg  2010-05-27  ...      2      0
# 4  6ozycU1RpktNG2-1BroVtw  2012-01-05  ...      0      0
#
# [5 rows x 10 columns]

# %%
yelp_df.shape
# Out:
# (10000, 10)

# %%
yelp15_df = (yelp_df.query(f"stars == 5 | stars == 1"))

# %%
(yelp15_df.stars
          .value_counts())
# Out:
# 5    3337
# 1     749
# Name: stars, dtype: int64

# %%
yelp_X, yelp_y = (yelp15_df.text, yelp15_df.stars)

# %%
yelp_Xtrain, yelp_Xtest, yelp_ytrain, yelp_ytest = train_test_split(yelp_X,
                                                                    yelp_y,
                                                                    test_size=0.2,
                                                                    random_state=20130810)

# %%
yelp_Xtrain, yelp_Xvalid, yelp_ytrain, yelp_yvalid = train_test_split(yelp_Xtrain,
                                                                      yelp_ytrain,
                                                                      test_size=0.2,
                                                                      random_state=20130810)

# %%
yelp_Xtrain.head()
# Out:
# 5313    I love Mexican food. Today I ate half of a tac...
# 9430    Great place - nice ambiance, cool decor, tasty...
# 1249    Anything I write will not do justice to this a...
# 9162    Going to Desert Botanical Garden is the perfec...
# 3814    My house is clean using pet-friendly products....
# Name: text, dtype: object

# %%
count_vectorizer = CountVectorizer(stop_words='english')

# %%
yelp_Xvec_train = count_vectorizer.fit_transform(yelp_Xtrain)

yelp_Xvec_valid = count_vectorizer.transform(yelp_Xvalid)
yelp_Xvec_test = count_vectorizer.transform(yelp_Xtest)

# %%
count_vectorizer.vocabulary_.keys()
# Out:
# dict_keys(['love', 'mexican', 'food', 'today', 'ate', 'half', 'taco', 'simply', 'stop', 'good', 'way', 'meat', 'tasted', 'like', 'frozen', 'multiple', 'times', 'lacked', 'flavor', 'tortilla', 'store', 'bought', 'paper', 'beans', 'flavorless', 'rice', 'hard', 'moving', 'vegetables', 'shredded', 'plastic', 'actually', 'vegtable', 'worst', 'tasting', 'priced', 'thing', 'reasonably', '10', 'absurd', 'fast', 'taste', 'margarita', 'bit', 'high', 'service', 'average', 'odd', 'waitress', 'didn', 'bite', 'item', 'missing', 'asked', 'great', 'place', 'nice', 'ambiance', 'cool', 'decor', 'tasty', 'going', 'check', 'spotted', 'donkey', 'finding', 'business', 'noticed', 'grassroots', 'parking', 'lot', 'decided', 'daughter', 'got', 'brisket', 'sandwich', 'let', 'try', 'combination', 'bbq', 'sauce', 'slaw', 'pickles', 'picked', 'fries', 'quite', 'tried', 'short', 'ribs', 'asian', 'fusion', 'asparagus', 'jalapeño', 'cheesy', 'grits', 've', 'fan', 'reminded', 'mom', 'used', 'make', 'finger', 'familiar', 'browned', 'toffee', 'flakes', 'gelato', 'capped', 'dinner', 'gotta', 'gadsden', 'flag', 'definitely', 'coming', 'apologies', 'attentive', 'helpful', 'server', 'having', 'demonstrative', 'appreciation', 'just', 'wasn', 'dang', 'mood', 'night', 'write', 'justice', 'awesome', 'hotel', 'stayed', 'dozen', 'past', 'years', 'fantastic', 'rooms', 'suite', 'extra', 'lucky', 'duck', 'basic', 'adorable', 'phenomenal', 'bathrooms', 'bar', 'restaurant', 'appetizers', 'wonderful', 'specialty', 'cocktails', 'fun', 'rat', 'pack', 'music', 'breakfast', 'better', 'restaurants', 'forget', 'comparing', 'standard', 'fare', 'location', 'plenty', 'shopping', 'bars', 'easy', 'walking', 'distance', 'normal', 'price', 'range', 'worth', 'penny', 'stay', 'phoenix', 'area', 'desert', 'botanical', 'garden', 'perfect', 'field', 'trip', 'beautiful', 'day', 'dbg', 'handful', 'events', 'exhibit', 'openings', 'meetings', 'course', 'yelp', 'bloom', 'yelper', 'party', 'planned', 'couple', 'ago', 'went', 'son', 'met', 'friends', 'sole', 'purpose', 'checking', 'butterfly', 'land', 'did', 'tons', 'gorgeous', 'butterflies', 'orange', 'yellow', 'striped', 'flowers', 'pavillion', 'pretty', 'look', 'visited', 'gift', 'kiosk', 'afterward', 'took', 'home', 'puppet', 'know', 'use', '25', 'runs', '13th', 'don', 'miss', 'time', 'design', 'living', 'world', 'saw', 'opened', 'really', 'photography', 'visit', 'wish', 'explore', 'house', 'clean', 'using', 'pet', 'friendly', 'products', 'arrive', 'reviews', 'talk', 'trouble', 'reaching', 'phone', 'problem', 'email', 'prefer', 'ladies', 'work', 'quickly', 'efficiently', 'couldn', 'happier', 'wait', 'stars', 'raw', 'chicken', 'bad', 'experience', '13', 'hadn', 'bandera', 'tonight', 'wow', 'started', 'grilled', 'artichoke', 'fabulous', 'texas', 'hill', 'country', 'came', 'cole', 'ordinary', 'delish', 'matchstick', 'unfortunately', 'eat', 'seeds', 'nuts', 'peanuts', 'husband', 'loved', 'polite', 'sarah', 'offered', 'sides', 'braised', 'red', 'cabbage', 'little', 'goat', 'cheese', 'die', 'entire', 'meal', 'superb', 'sit', 'kitchen', 'dishes', 'come', 'looked', 'yummy', 'happy', 'neighbor', 'suggested', 'frequently', 'tell', 'run', 'tight', 'ship', 'polished', 'efficient', 'perfection', 'tip', 'll', 'pictures', 'hungry', 'think', 'shorts', 'jeans', 'type', 'dressy', 'casual', 'mean', 'excellent', 'patio', 'classic', 'hour', 'glasses', 'wine', 'calamari', 'charts', 'sitting', 'hot', 'schwetty', 'kept', 'umbrellas', 'shade', 'sun', 'set', 'misleading', 'charming', 'dining', 'spot', 'eaten', 'dined', 'lunch', 'friend', 'blown', 'away', 'tucked', 'near', 'asu', 'campus', 'quiet', 'neighborhood', 'appears', 'converted', 'built', 'early', '1900', 'lots', 'mature', 'trees', 'plants', 'growing', 'huge', 'outdoor', 'outside', 'honestly', 'weather', 'months', 'year', 'dine', 'staff', 'extremely', 'checked', 'drank', 'water', 'waited', 'menu', 'amazing', 'read', 'wanted', 'variety', 'american', 'french', 'divine', 'told', 'changes', 'new', 'seasonal', 'offer', 'r ...

# %%
words_df = pd.DataFrame(yelp_Xvec_train.toarray(), 
                        columns=count_vectorizer.get_feature_names())

words_frequency = pd.DataFrame(words_df.sum(axis=0)).reset_index()

words_frequency.columns = ['word', 'frequency']

(words_frequency.sort_values(by='frequency',
                             ascending=False)
                .head(10))
# Out:
#           word  frequency
# 10256    place       1605
# 5477      food       1495
# 6101     great       1326
# 6001      good       1283
# 7982      like       1118
# 7511      just       1082
# 13899     time        841
# 12105  service        810
# 14595       ve        760
# 8185      love        738

# %% [markdown]
# ## Model

# %%
learner_multiomialnb = MultinomialNB()

# %%
# %%time

learner_multiomialnb.fit(yelp_Xvec_train,
                         yelp_ytrain)
# Out:
# CPU times: user 3.96 ms, sys: 3.15 ms, total: 7.11 ms
# Wall time: 7.23 ms
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
learner_multiomialnb.score(yelp_Xvec_train,
                           yelp_ytrain)
# Out:
# 0.9797245600612089

# %%
confusion_matrix(yelp_yvalid,
                 learner_multiomialnb.predict(yelp_Xvec_valid))
# Out:
# array([[ 68,  52],
#        [ 15, 519]])

# %%
print(classification_report(yelp_yvalid,
                            learner_multiomialnb.predict(yelp_Xvec_valid)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.82      0.57      0.67       120
#            5       0.91      0.97      0.94       534
#
#     accuracy                           0.90       654
#    macro avg       0.86      0.77      0.80       654
# weighted avg       0.89      0.90      0.89       654

# %% [markdown]
# # Example: **Diabetes**

# %% [markdown]
# ##Data

# %%
diabetes_df = pd.read_csv("https://raw.githubusercontent.com/npradaschnor/Pima-Indians-Diabetes-Dataset/master/diabetes.csv")

# %%
diabetes_X, diabetes_y = (diabetes_df.drop('Outcome', axis=1), 
                          diabetes_df.Outcome)

# %%
diabetes_Xtrain, diabetes_Xtest, diabetes_ytrain, diabetes_ytest = train_test_split(diabetes_X,
                                                                                    diabetes_y,
                                                                                    test_size=0.2,
                                                                                    random_state=20130810)

diabetes_Xtrain, diabetes_Xvalid, diabetes_ytrain, diabetes_yvalid = train_test_split(diabetes_Xtrain,
                                                                                      diabetes_ytrain,
                                                                                      test_size=0.2,
                                                                                      random_state=20130810)

# %% [markdown]
# ## Model

# %%
learner_gaussiannb = GaussianNB()

# %%
learner_gaussiannb.fit(diabetes_Xtrain, diabetes_ytrain)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
print(classification_report(diabetes_yvalid,
                            learner_gaussiannb.predict(diabetes_Xvalid)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.91      0.84        79
#            1       0.77      0.55      0.64        44
#
#     accuracy                           0.78       123
#    macro avg       0.78      0.73      0.74       123
# weighted avg       0.78      0.78      0.77       123
